# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.5f}'.format

# %%
combined_df = pd.read_csv('datasets/combined_dataset.csv')
train = pd.read_csv('datasets/KDDTrain+.csv')
test = pd.read_csv('datasets/KDDTest+.csv')
comp_df1 = pd.read_csv('/Users/ryan/Desktop/ICASSP2021/1203_firewall.csv')
comp_df2 = pd.read_csv('/Users/ryan/Desktop/ICASSP2021/1210_firewall.csv')
comp_df3 = pd.read_csv('/Users/ryan/Desktop/ICASSP2021/1216_firewall.csv')

# %%
test['attack_type'].unique()
# Out:
# array(['neptune', 'normal', 'saint', 'mscan', 'guess_passwd', 'smurf',
#        'apache2', 'satan', 'buffer_overflow', 'back', 'warezmaster',
#        'snmpgetattack', 'processtable', 'pod', 'httptunnel', 'nmap', 'ps',
#        'snmpguess', 'ipsweep', 'mailbomb', 'portsweep', 'multihop',
#        'named', 'sendmail', 'loadmodule', 'xterm', 'worm', 'teardrop',
#        'rootkit', 'xlock', 'perl', 'land', 'xsnoop', 'sqlattack',
#        'ftp_write', 'imap', 'udpstorm', 'phf'], dtype=object)

# %%
comp_df3['label'].unique()
# Out:
# array(['Normal', 'DDOS-smurf', 'Probing-IP sweep', 'Probing-Nmap',
#        'Probing-Port sweep'], dtype=object)

# %%
# comp_df3.loc[comp_df3.label != 'Normal', 'label'] = 'Attack'

# %%
comp_df3.loc[comp_df3.label == 'Probing-IP sweep'].count()
# Out:
# time                 58
# src                  58
# dst                  58
# spt                  58
# dpt                  58
# duration             58
# out (bytes)          58
# in (bytes)           58
# proto                58
# app                  58
# cnt_dst              58
# cnt_src              58
# cnt_serv_src         58
# cnt_serv_dst         58
# cnt_dst_slow         58
# cnt_src_slow         58
# cnt_serv_src_slow    58
# cnt_serv_dst_slow    58
# cnt_dst_conn         58
# cnt_src_conn         58
# cnt_serv_src_conn    58
# cnt_serv_dst_conn    58
# label                58
# dtype: int64

# %%
for i in range(0, 487):
    train = train.append(pd.Series(dtype = 'float64'), ignore_index=True)
train
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes    land  \
# 0        0.00000           tcp  ftp_data   SF  491.00000    0.00000 0.00000
# 1        0.00000           udp     other   SF  146.00000    0.00000 0.00000
# 2        0.00000           tcp   private   S0    0.00000    0.00000 0.00000
# 3        0.00000           tcp      http   SF  232.00000 8153.00000 0.00000
# 4        0.00000           tcp      http   SF  199.00000  420.00000 0.00000
# ...          ...           ...       ...  ...        ...        ...     ...
# 127560       nan           NaN       NaN  NaN        nan        nan     nan
# 127561       nan           NaN       NaN  NaN        nan        nan     nan
# 127562       nan           NaN       NaN  NaN        nan        nan     nan
# 127563       nan           NaN       NaN  NaN        nan        nan     nan
# 127564       nan           NaN       NaN  NaN        nan        nan     nan
#
# ...

# %%
train['attack_type'] = train['attack_type'].fillna('portsweep')
train = train.replace(np.nan, 0)

train
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes    land  \
# 0        0.00000           tcp  ftp_data   SF  491.00000    0.00000 0.00000
# 1        0.00000           udp     other   SF  146.00000    0.00000 0.00000
# 2        0.00000           tcp   private   S0    0.00000    0.00000 0.00000
# 3        0.00000           tcp      http   SF  232.00000 8153.00000 0.00000
# 4        0.00000           tcp      http   SF  199.00000  420.00000 0.00000
# ...          ...           ...       ...  ...        ...        ...     ...
# 127560   0.00000             0         0    0    0.00000    0.00000 0.00000
# 127561   0.00000             0         0    0    0.00000    0.00000 0.00000
# 127562   0.00000             0         0    0    0.00000    0.00000 0.00000
# 127563   0.00000             0         0    0    0.00000    0.00000 0.00000
# 127564   0.00000             0         0    0    0.00000    0.00000 0.00000
#
# ...

# %%
print(f'{train.attack_type.unique()}\n\n{test.attack_type.unique()}')

# %%
print(train.groupby(['attack_type']).size().sort_values(ascending = True))
print()
print(test.groupby(['attack_type']).size().sort_values(ascending = True))

# %%
print(comp_df1.groupby(['label']).size().sort_values(ascending = True))
print()
print(comp_df2.groupby(['label']).size().sort_values(ascending = True))
print()
print(comp_df3.groupby(['label']).size().sort_values(ascending = True))

# %%
print(f'{comp_df1.label.unique()}\n\n {comp_df2.label.unique()}\n\n {comp_df3.label.unique()}')

# %%
comp_df1

# %%
train
