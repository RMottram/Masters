# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.5f}'.format

# %%
combined_df = pd.read_csv('datasets/combined_dataset.csv')
train = pd.read_csv('datasets/KDDTrain+.csv')
test = pd.read_csv('datasets/KDDTest+.csv')
comp_df1 = pd.read_csv('/Users/ryan/Desktop/ICASSP2021/1203_firewall.csv')
comp_df2 = pd.read_csv('/Users/ryan/Desktop/ICASSP2021/1210_firewall.csv')
comp_df3 = pd.read_csv('/Users/ryan/Desktop/ICASSP2021/1216_firewall.csv')

# %%
combined_df
# Out:
#         duration  src_bytes  dst_bytes    land  wrong_fragment  urgent  \
# 0        0.00000    0.00009    0.00000 0.00000         0.00000 0.00000
# 1        0.00000    0.00003    0.00000 0.00000         0.00000 0.00000
# 2        0.00000    0.00000    0.00000 0.00000         0.00000 0.00000
# 3        0.00000    0.00004    0.00159 0.00000         0.00000 0.00000
# 4        0.00000    0.00004    0.00008 0.00000         0.00000 0.00000
# ...          ...        ...        ...     ...             ...     ...
# 147703   0.00442    0.00048    0.00006 0.00000         0.00000 0.00000
# 147704   0.00000    0.00015    0.00006 0.00000         0.00000 0.00000
# 147705   0.00000    0.00006    0.00018 0.00000         0.00000 0.00000
# 147706   0.00000    0.01008    0.00162 0.00000         0.00000 0.00000
# 147707   0.00000    0.00000    0.00000 0.00000         0.00000 0.00000
#
#            hot  num_failed_logins  logged_in  num_compromised  root_shell  \
# ...

# %%
comp_df3
# Out:
#                         time            src              dst    spt   dpt  \
# 0        2020-12-15 03:36:15  172.24.65.119    172.24.68.145      0     0
# 1        2020-12-15 03:36:15  172.24.65.124  239.255.255.250  50459  1900
# 2        2020-12-15 03:36:15     10.1.1.253     172.24.78.98   1027  6343
# 3        2020-12-15 03:36:16  172.24.65.169     172.24.78.18  54294   389
# 4        2020-12-15 03:36:15  172.24.65.169     172.24.78.18  54294   389
# ...                      ...            ...              ...    ...   ...
# 3165963  2020-12-16 16:56:17  172.24.65.158      172.24.78.8  55510    53
# 3165964  2020-12-16 16:56:17  172.24.65.158     40.126.12.32   1802   443
# 3165965  2020-12-16 16:56:17  172.24.65.158  104.115.250.223   1794   443
# 3165966  2020-12-16 16:56:17  172.24.65.158  104.115.250.223   1794   443
# 3165967  2020-12-16 16:56:17   172.24.65.40     172.24.78.18  62257   445
#
#          duration  out (bytes)  in (bytes)  proto           app  cnt_dst  \
# ...

# %%
comp_df3.loc[comp_df3.label != 'Normal', 'label'] = 'Attack'

# %%
comp_df3.loc[comp_df3.label == 'Attack']
# Out:
#                         time              src             dst  spt    dpt  \
# 1614166  2020-12-15 17:58:39     172.24.65.71   172.24.87.255    0      0
# 1632999  2020-12-15 18:06:35     172.24.78.78   172.24.93.255    0      0
# 1707613  2020-12-15 19:21:38  103.245.120.131    172.67.22.84  445  42842
# 1707614  2020-12-15 19:21:38  103.245.120.131    172.67.22.85  445  42842
# 1707615  2020-12-15 19:21:38  103.245.120.131    172.67.22.86  445  42842
# ...                      ...              ...             ...  ...    ...
# 3067704  2020-12-16 16:06:21    207.46.13.159   52.210.12.255    0      0
# 3067705  2020-12-16 16:06:21    207.46.13.159   52.210.12.255    0      0
# 3067706  2020-12-16 16:06:21    207.46.13.159   52.210.12.255    0      0
# 3067710  2020-12-16 16:06:21    207.46.13.159   52.210.12.255    0      0
# 3100121  2020-12-16 16:22:14    104.198.89.53  152.195.35.255    0      0
#
#          duration  out (bytes)  in (bytes)  cnt_dst  cnt_src  cnt_serv_src  \
# ...

# %%
import random
test = pd.DataFrame(np.random.uniform(0,255,size=(1592, 115)), columns=combined_df.columns)

# %%
test
# Out:
#       duration  src_bytes  dst_bytes      land  wrong_fragment    urgent  \
# 0    168.97858  248.67227  106.22024  63.84007        83.62166 241.84502
# 1    243.90388   49.95205  232.72924  85.71716       137.08821 226.23960
# 2     76.70898   92.02911   23.40317 155.34572       213.75597  77.54325
# 3    105.35897  152.45639  103.97129 121.12977       151.59982 168.85419
# 4    232.87071    9.32488   36.02397 203.52249       217.31316 247.20812
# ...        ...        ...        ...       ...             ...       ...
# 1587  52.48671   47.54530  137.24499 238.50054       122.42191 160.22218
# 1588 187.17614   71.89997  185.22506 111.17394       219.45465 100.01693
# 1589   6.74086    5.01247  128.10176 151.82742       164.90732  53.54690
# 1590  71.01162  172.78122  245.04942  91.44042       156.86975 139.37362
# 1591  69.50375   19.66140   24.86830 114.44668       248.04400 233.90851
#
#            hot  num_failed_logins  logged_in  num_compromised  root_shell  \
# ...

# %%
comp_df3['app'].unique()
# Out:
# array(['icmp', 'ssdp', 'others', 'domain', 'https', 'http',
#        'microsoft-ds', 'snmp', 'igmp', 'netbios-ns', 'netbios-dgm', 'ftp',
#        'syslog', 'rtsp', 'roadrunner', 'ssh', 'nfs', 'snmp-trap',
#        'bootps', 'bootpc', 'real-audio', 'netbios-ssn', 'smtp', 'h323',
#        'pptp', 'telnet', 'auth', 'pop3', 'vdolive', 'nntp', 'finger',
#        'rexec', 'sql-net', 'news', 'aim', 'rlogin', 'msn', 'isakmp',
#        'irc', 'rcmd', 'bgp', 'tftp', 'sftp'], dtype=object)

# %%
print(f'{train.attack_type.unique()}\n\n{test.attack_type.unique()}')

# %%
print(train.groupby(['attack_type']).size().sort_values(ascending = True))
print()
print(test.groupby(['attack_type']).size().sort_values(ascending = True))

# %%
print(comp_df1.groupby(['label']).size().sort_values(ascending = True))
print()
print(comp_df2.groupby(['label']).size().sort_values(ascending = True))
print()
print(comp_df3.groupby(['label']).size().sort_values(ascending = True))

# %%
print(f'{comp_df1.label.unique()}\n\n {comp_df2.label.unique()}\n\n {comp_df3.label.unique()}')

# %%
comp_df1

# %%
train
